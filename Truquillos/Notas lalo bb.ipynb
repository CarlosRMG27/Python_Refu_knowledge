# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Order Details Kaggle.csv')
df2=pd.read_csv('kaggle_db_metrics.csv')

# %%
df
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1     B-25601    66.0   -12.0         5     Clothing             Stole
# 2     B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3     B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4     B-25602   168.0  -111.0         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099   835.0   267.0         5  Electronics            Phones
# 1496  B-26099  2366.0   552.0         5     Clothing          Trousers
# 1497  B-26100   828.0   230.0         2    Furniture            Chairs
# 1498  B-26100    34.0    10.0         2     Clothing           T-shirt
# 1499  B-26100    72.0    16.0         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
tabla=pd.pivot_table(df,values='Amount',index=['Sub-Category'],aggfunc=np.sum)
tabla
# Out:
#                    Amount
# Sub-Category
# Accessories       21728.0
# Bookcases         56861.0
# Chairs            34222.0
# Electronic Games  39168.0
# Furnishings       13484.0
# Hankerchief       14608.0
# Kurti              3361.0
# Leggings           2106.0
# Phones            46119.0
# Printers          58252.0
# Saree             53511.0
# Shirt              7555.0
# Skirt              1946.0
# Stole             18546.0
# T-shirt            7382.0
# Tables            22614.0
# Trousers          30039.0

# %%
P=df.groupby(['Sub-Category'])['Amount'].sum().reset_index()
P
# Out:
#         Sub-Category   Amount
# 0        Accessories  21728.0
# 1          Bookcases  56861.0
# 2             Chairs  34222.0
# 3   Electronic Games  39168.0
# 4        Furnishings  13484.0
# 5        Hankerchief  14608.0
# 6              Kurti   3361.0
# 7           Leggings   2106.0
# 8             Phones  46119.0
# 9           Printers  58252.0
# 10             Saree  53511.0
# 11             Shirt   7555.0
# 12             Skirt   1946.0
# 13             Stole  18546.0
# 14           T-shirt   7382.0
# 15            Tables  22614.0
# 16          Trousers  30039.0

# %%
P=df.groupby(['Sub-Category']).agg({'Amount':'sum','Profit':'mean'}).reset_index()
P
# Out:
#         Sub-Category   Amount      Profit
# 0        Accessories  21728.0   49.430556
# 1          Bookcases  56861.0   61.873418
# 2             Chairs  34222.0    7.797297
# 3   Electronic Games  39168.0  -15.645570
# 4        Furnishings  13484.0   11.561644
# 5        Hankerchief  14608.0   10.595960
# 6              Kurti   3361.0    3.851064
# 7           Leggings   2106.0    4.905660
# 8             Phones  46119.0   26.590361
# 9           Printers  58252.0   80.594595
# 10             Saree  53511.0    1.676190
# 11             Shirt   7555.0   16.391304
# 12             Skirt   1946.0    3.671875
# 13             Stole  18546.0   13.328125
# 14           T-shirt   7382.0   19.480519
# 15            Tables  22614.0 -235.941176
# 16          Trousers  30039.0   73.000000

# %%
df3=pd.merge(df2,P,left_on=['prod_A'],right_on=['Sub-Category'])

# %%
pd.merge(df3,P,left_on=['prod_B'],right_on=['Sub-Category'])
# Out:
#                prod_A     prod_B  p_a_b  p_a  transacciones_totales  p_b  \
# 0           Bookcases      Stole     26   72                    500  157
# 1         Hankerchief      Stole     59  138                    500  157
# 2    Electronic Games      Stole     27   73                    500  157
# 3              Phones      Stole     23   71                    500  157
# 4               Saree      Stole     58  156                    500  157
# ..                ...        ...    ...  ...                    ...  ...
# 267            Tables  Bookcases      2   16                    500   72
# 268          Printers  Bookcases     18   67                    500   72
# 269       Accessories  Bookcases     14   65                    500   72
# 270       Furnishings  Bookcases     10   66                    500   72
# 271             Skirt  Bookcases      8   56                    500   72
#
#      support_a_b  support_a  support_b  confidence  ...  sales_a  sales_b  \
# ...

# %%
df.groupby(['Sub-Category'])['Order ID','Amount'].count()
# Out:
# <ipython-input-20-dcea75ed9f0d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Sub-Category'])['Order ID','Amount'].count()
#                   Order ID  Amount
# Sub-Category
# Accessories             72      72
# Bookcases               79      79
# Chairs                  74      74
# Electronic Games        79      79
# Furnishings             73      73
# Hankerchief            198     198
# Kurti                   47      47
# Leggings                53      53
# Phones                  83      83
# Printers                74      74
# Saree                  210     210
# Shirt                   69      69
# Skirt                   64      64
# Stole                  192     192
# T-shirt                 77      77
# Tables                  17      17
# Trousers                39      39

# %%
d={'Columna1':[1,2,3,4],'Columna2':[3,4,5,6]}
D=pd.DataFrame(d)
D
# Out:
#    Columna1  Columna2
# 0         1         3
# 1         2         4
# 2         3         5
# 3         4         6

# %%
D['Columna3']=np.where(D['Columna1'].values<3,0,1)
D
# Out:
#    Columna1  Columna2  Columna3
# 0         1         3         0
# 1         2         4         0
# 2         3         5         1
# 3         4         6         1
